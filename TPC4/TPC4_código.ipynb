# %% [markdown]
# ### TPC4: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um elemento na lista, se o encontrar deverá devolver a sua posição, devolverá -1 se o elemento não estiver na lista;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
Menu=("Menu:\n(1) Cria lista\n(2) Lê lista \n(3) Soma \n(4) Média \n(5) Maior \n(6) Menor \n(7) Está Ordenada por ordem crescente \n(8) Está ordenada por ordem decrescente \n(9) Procura um elemento /n(0) Sair")
print(Menu)
opçao=int(input("Bem Vindo! Escolha o número que corresponde ao que quer executar."))
import random
lista=[]

while opçao !=0:
    if opçao == 1:
        lista=[]
        N=int(input("Introduza o número de elementos que quer que componha a lista"))
        for n in range(0,N):
            n=int(random.randrange(0,100))
            lista.append(n)
        print("A sua lista é " + str(lista))

        print(Menu)
        opçao=int(input("De seguida que operaçao pretende executar?"))

    elif opçao == 2:
        lista=[]
        B=int(input("Introduza o número de elementos que quer que companha a sua lista"))
        for n in range(0,B):
            n=int(input("Introduza um número para fazer parte da lista"))
            lista.append(n)
        print("A sua lista é " + str(lista))
        
        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 3:
        soma = 0
        for n in lista:
            soma = soma + n
        print("A soma é " + str(soma))

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 4:
        divisor=len(lista)
        media=soma/divisor
        soma = 0
        i = 0
        while i < len(lista):
            soma = soma + N
            i = i + 1
        print("A média é " + str(media))

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 5:
        maior = 0
        for n in lista:
            if n > maior:
                maior=N
        print("o maior elemento é " + str(maior))

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 6 :
        menor=lista[0]
        for n in lista[1]:
            if n < menor:
                menor=n 
        print("O menor elemento é " + str(menor))

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 7:
        tamanho=len(lista)
        ordem="Sim"
        for n in range (0,tamanho-1):
            if lista[n] > lista[n+1]:
                ordem="Não"
        print(ordem)

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 8:
        tamanho=len(lista)
        ordem="Sim"
        for n in range(0,tamanho-1):
            if lista[n]<lista[n+1]:
                ordem="Não"
        print(ordem)

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

    elif opçao == 9:
        elemento=int(input("Qual é o elemento que procura?"))
        if elemento in lista:
            x=lista.index(elemento)
        else:
            x = -1
        print("O índice do elemento na lista é " + str(x))

        print(Menu)
        opçao=int(input("De seguida que operação pretende executar?"))

if opçao == 0:
    print("A lista guardada foi" + str(lista))
# Out:
# Menu:
# (1) Cria lista
# (2) Lê lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) Está Ordenada por ordem crescente
# (8) Está ordenada por ordem decrescente
# (9) Procura um elemento /n(0) Sair
# A sua lista é[4, 55, 86]
# Menu:
# (1) Cria lista
# (2) Lê lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) Está Ordenada por ordem crescente
# (8) Está ordenada por ordem decrescente
# (9) Procura um elemento /n(0) Sair
# A sua lista é[2, 4, 5]
# Menu:
# (1) Cria lista
# (2) Lê lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) Está Ordenada por ordem crescente
# (8) Está ordenada por ordem decrescente
# (9) Procura um elemento /n(0) Sair
# A soma é11
# Menu:
# (1) Cria lista
# (2) Lê lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) Está Ordenada por ordem crescente
# (8) Está ordenada por ordem decrescente
# (9) Procura um elemento /n(0) Sair
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 37
#      34     print("A soma é" + str(soma))
#      36     print(Menu)
# ---> 37     opçao=int(input("De seguida que operação pretende executar?"))
#      39 elif opçao == 4:
#      40     divisor=len(lista)
#
# ValueError: invalid literal for int() with base 10: ''
